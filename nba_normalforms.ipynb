# %%
import numpy as np
import pandas as pd
import psycopg
from sqlalchemy import create_engine
import dotenv
import os
import sqlite3
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import psycopg
#       4 from sqlalchemy import create_engine
#       5 import dotenv
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\psycopg\__init__.py:9
#       5 # Copyright (C) 2020 The Psycopg Team
#       7 import logging
# ----> 9 from . import pq  # noqa: F401 import early to stabilize side effects
#      10 from . import types
#      11 from . import postgres
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\psycopg\pq\__init__.py:118
#     109         sattempts = "\n".join(f"- {attempt}" for attempt in attempts)
#     110         raise ImportError(
#     111             f"""\
#     112 no pq wrapper available.
#     113 Attempts made:
#     114 {sattempts}"""
#     115         )
# --> 118 import_from_libpq()
#     120 __all__ = (
#     121     "ConnStatus",
#     122     "PipelineStatus",
#    (...)
#     137     "version_pretty",
#     138 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\psycopg\pq\__init__.py:110, in import_from_libpq()
#     108     else:
#     109         sattempts = "\n".join(f"- {attempt}" for attempt in attempts)
# --> 110         raise ImportError(
#     111             f"""\
#     112 no pq wrapper available.
#     113 Attempts made:
#     114 {sattempts}"""
#     115         )
#
# ImportError: no pq wrapper available.
# Attempts made:
# - couldn't import psycopg 'c' implementation: No module named 'psycopg_c'
# - couldn't import psycopg 'binary' implementation: No module named 'psycopg_binary'
# - couldn't import psycopg 'python' implementation: libpq library not found

# %%
nba = pd.read_csv('ASA All NBA Raw Data.csv', low_memory=False)

# %%
pd.set_option('display.max_rows', 81)
nba.head(3).T
# Out:
#                                                                               0  \
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                            Corey Kispert
# player_id                                                             kispeco01
# starter                                                                       1
# mp                                                                        32:30
# fg                                                                            6
# fga                                                                           9
# fg_pct                                                                    0.667
# fg3                                                                           4
# fg3a                                                                          6
# fg3_pct                                                                   0.667
# ft                                                                            0
# fta                                                                           0
# ft_pct                                                                      0.0
# orb                                                                           0
# drb                                                                           1
# trb                                                                           1
# ast                                                                           1
# stl                                                                           2
# blk                                                                           0
# tov                                                                           2
# pf                                                                            2
# pts                                                                          16
# plus_minus                                                                   13
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                    0.889
# efg_pct                                                                   0.889
# fg3a_per_fga_pct                                                          0.667
# fta_per_fga_pct                                                             0.0
# orb_pct                                                                     0.0
# drb_pct                                                                     3.3
# trb_pct                                                                     1.8
# ast_pct                                                                     4.0
# stl_pct                                                                     3.1
# blk_pct                                                                     0.0
# tov_pct                                                                    18.2
# usg_pct                                                                    15.6
# off_rtg                                                                     133
# def_rtg                                                                     113
# bpm                                                                         3.1
# season                                                                     2022
# minutes                                                                    32.5
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       23.75
# FDP                                                                        22.7
# SDP                                                                       24.75
# DKP_per_minute                                                0.730769230769231
# FDP_per_minute                                                0.698461538461538
# SDP_per_minute                                                0.761538461538461
# pf_per_minute                                                          0.061538
# ts                                                                          9.0
# last_60_minutes_per_game_starting                                     31.716667
# last_60_minutes_per_game_bench                                        22.017778
# PG%                                                                         1.0
# SG%                                                                        36.0
# SF%                                                                        60.0
# PF%                                                                         4.0
# C%                                                                          0.0
# active_position_minutes                                               46.253586
#
#                                                                               1  \
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                               Kyle Kuzma
# player_id                                                             kuzmaky01
# starter                                                                       1
# mp                                                                        30:16
# fg                                                                            2
# fga                                                                           7
# fg_pct                                                                    0.286
# fg3                                                                           0
# fg3a                                                                          3
# fg3_pct                                                                     0.0
# ft                                                                            1
# fta                                                                           1
# ft_pct                                                                      1.0
# orb                                                                           0
# drb                                                                           7
# trb                                                                           7
# ast                                                                           5
# stl                                                                           1
# blk                                                                           0
# tov                                                                           7
# pf                                                                            3
# pts                                                                           5
# plus_minus                                                                   10
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                    0.336
# efg_pct                                                                   0.286
# fg3a_per_fga_pct                                                          0.429
# fta_per_fga_pct                                                           0.143
# orb_pct                                                                     0.0
# drb_pct                                                                    24.7
# trb_pct                                                                    13.9
# ast_pct                                                                    18.5
# stl_pct                                                                     1.7
# blk_pct                                                                     0.0
# tov_pct                                                                    48.5
# usg_pct                                                                    22.0
# off_rtg                                                                      55
# def_rtg                                                                     107
# bpm                                                                       -15.5
# season                                                                     2022
# minutes                                                               30.266667
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       19.75
# FDP                                                                        16.9
# SDP                                                                       17.25
# DKP_per_minute                                                0.652533039647577
# FDP_per_minute                                                0.558370044052863
# SDP_per_minute                                                0.569933920704846
# pf_per_minute                                                          0.099119
# ts                                                                         7.44
# last_60_minutes_per_game_starting                                        34.324
# last_60_minutes_per_game_bench                                        18.475954
# PG%                                                                         0.0
# SG%                                                                         0.0
# SF%                                                                         4.0
# PF%                                                                        85.0
# C%                                                                         11.0
# active_position_minutes                                                52.15259
#
#                                                                               2
# game_id                                                            202202170BRK
# game_date                                                            2022-02-17
# OT                                                                            0
# H_A                                                                           A
# Team_Abbrev                                                                 WAS
# Team_Score                                                                  117
# Team_pace                                                                  94.5
# Team_efg_pct                                                              0.627
# Team_tov_pct                                                               13.5
# Team_orb_pct                                                               22.9
# Team_ft_rate                                                              0.157
# Team_off_rtg                                                              123.8
# Inactives                          Joel Ayayi, Bradley Beal, Kristaps Porzingis
# Opponent_Abbrev                                                             BRK
# Opponent_Score                                                              103
# Opponent_pace                                                              94.5
# Opponent_efg_pct                                                          0.483
# Opponent_tov_pct                                                           13.1
# Opponent_orb_pct                                                           33.3
# Opponent_ft_rate                                                          0.191
# Opponent_off_rtg                                                          109.0
# player                                                 Kentavious Caldwell-Pope
# player_id                                                             caldwke01
# starter                                                                       1
# mp                                                                        25:26
# fg                                                                            3
# fga                                                                           7
# fg_pct                                                                    0.429
# fg3                                                                           1
# fg3a                                                                          3
# fg3_pct                                                                   0.333
# ft                                                                            0
# fta                                                                           0
# ft_pct                                                                      0.0
# orb                                                                           1
# drb                                                                           4
# trb                                                                           5
# ast                                                                           2
# stl                                                                           1
# blk                                                                           0
# tov                                                                           1
# pf                                                                            0
# pts                                                                           7
# plus_minus                                                                   13
# did_not_play                                                                  0
# is_inactive                                                                   0
# ts_pct                                                                      0.5
# efg_pct                                                                     0.5
# fg3a_per_fga_pct                                                          0.429
# fta_per_fga_pct                                                             0.0
# orb_pct                                                                     5.4
# drb_pct                                                                    16.8
# trb_pct                                                                    11.8
# ast_pct                                                                     9.4
# stl_pct                                                                     2.0
# blk_pct                                                                     0.0
# tov_pct                                                                    12.5
# usg_pct                                                                    14.5
# off_rtg                                                                     106
# def_rtg                                                                     110
# bpm                                                                        -3.8
# season                                                                     2022
# minutes                                                               25.433333
# double_double                                                                 0
# triple_double                                                                 0
# DKP                                                                       18.25
# FDP                                                                        18.0
# SDP                                                                       18.75
# DKP_per_minute                                                0.717562254259502
# FDP_per_minute                                                0.707732634338139
# SDP_per_minute                                                0.737221494102228
# pf_per_minute                                                               0.0
# ts                                                                          7.0
# last_60_minutes_per_game_starting                                      29.82029
# last_60_minutes_per_game_bench                                        16.051693
# PG%                                                                         0.0
# SG%                                                                        32.0
# SF%                                                                        67.0
# PF%                                                                         0.0
# C%                                                                          0.0
# active_position_minutes                                               47.021807

# %% [markdown]
# ## Database Normalization
# ### First normal form:
#
# 1. **All tables must have a primary key**: In this table, `game_id` and `player_id` together are unique on every row, and so they form primary key.
#
# 2. **All the data must be atomic**: Inactives is non-atomic.
#
# 3. **No repeating groups problem**: We can't solve the non-atomicity problem by creating separate columns if this leads to arbitrary ordering language in the column names (for example, `Inactive1`, `Inactive2`, etc.) and if it leads to a lot of missing data (there would be an `Inactive7` which would be missing any time a team has less than 7 inactive players).

# %% [markdown]
# ### Functional Dependence
# Let X and Y be columns in a data table. Y is functionally dependent on X if each value of X has exactly one value of Y.
#
# That's pretty abstract. So here are some guidelines that help me:
#
# 1. This use of "function" is the exact same as the concept of a function from algebra and pre-calculus. A correspondence f(x)=y is a function if each value of x has only one associated value of y.
#
# 2. X is either a primary key, or something that should be a primary key in another table.
#
# For example, `game_date` (Y) is functionally dependent on `game_id` (X) because one `game_id` takes place on exactly one date.
#
# ### Second normal form:
# In this table the primary key is a superkey consisting of two columns: `game_id` and `player_id`.
#
# 2NF is violated if any columns are functionally dependent on part of the primary key but not the entire primary key. This can only happen if the primary key is a superkey.

# %% [markdown]
# ### Third normal form:
# 3NF is violated if there are "transitive dependencies", that is, functional dependence between columns when neither column is part of the primary key.
